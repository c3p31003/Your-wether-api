# %% [markdown]
# # Load the dataframe

# %%
import pandas as pd

# %%
df = pd.read_csv("data_small/TG_STAID000001.txt", skiprows=20, parse_dates=["    DATE"])

# %%
print(df)
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 59316      1   35381 2022-05-27  -9999      9
# 59317      1   35381 2022-05-28  -9999      9
# 59318      1   35381 2022-05-29  -9999      9
# 59319      1   35381 2022-05-30  -9999      9
# 59320      1   35381 2022-05-31  -9999      9
#
# [59321 rows x 5 columns]

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 59316      1   35381 2022-05-27  -9999      9
# 59317      1   35381 2022-05-28  -9999      9
# 59318      1   35381 2022-05-29  -9999      9
# 59319      1   35381 2022-05-30  -9999      9
# 59320      1   35381 2022-05-31  -9999      9
#
# [59321 rows x 5 columns]

# %% [markdown]
# # Show certain rows

# %%
df[10:20]
# Out:
#     STAID   SOUID       DATE     TG   Q_TG
# 10      1   35381 1860-01-11     -5      0
# 11      1   35381 1860-01-12    -18      0
# 12      1   35381 1860-01-13    -27      0
# 13      1   35381 1860-01-14    -26      0
# 14      1   35381 1860-01-15    -37      0
# 15      1   35381 1860-01-16     -9      0
# 16      1   35381 1860-01-17      7      0
# 17      1   35381 1860-01-18     -6      0
# 18      1   35381 1860-01-19    -16      0
# 19      1   35381 1860-01-20    -19      0

# %% [markdown]
# # Show certain columns

# %%
df.columns
# Out:
# Index(['STAID', ' SOUID', '    DATE', '   TG', ' Q_TG'], dtype='str')

# %%
df[ '   TG']
# Out:
# 0          21
# 1          46
# 2          31
# 3          37
# 4          31
#          ...
# 59316   -9999
# 59317   -9999
# 59318   -9999
# 59319   -9999
# 59320   -9999
# Name:    TG, Length: 59321, dtype: int64

# %%
df[["   TG","    DATE"]]
# Out:
#          TG       DATE
# 0        21 1860-01-01
# 1        46 1860-01-02
# 2        31 1860-01-03
# 3        37 1860-01-04
# 4        31 1860-01-05
# ...     ...        ...
# 59316 -9999 2022-05-27
# 59317 -9999 2022-05-28
# 59318 -9999 2022-05-29
# 59319 -9999 2022-05-30
# 59320 -9999 2022-05-31
#
# [59321 rows x 2 columns]

# %% [markdown]
# # Simple statistics and filterring

# %%
df.loc[df["   TG"] != -9999]["   TG"].mean() / 10
# Out:
# np.float64(6.360787526128467)

# %%
df.loc[df["   TG"] != -9999]["   TG"].max() / 10
# Out:
# np.float64(26.2)

# %%
df.loc[df["   TG"] != -9999]["   TG"].min() / 10
# Out:
# np.float64(-28.8)

# %%
#%pip install matplotlib
# Out:
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/d0/9f/970fcbf381e82ec66fdf5da8ea76e2e9240f61a24011ce9fd1d42c37ac2d/matplotlib-3.11.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached matplotlib-3.11.0-cp311-cp311-win_amd64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/98/4b/9bd370b004b5c9d8045c6c33cf65bae018b27aca550a3f657cdc99acdbd8/contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata
#   Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/08/60/defa5e69641db890a63be281f41345f4c33b157824eaf0b9fad3e08b0dcb/fonttools-4.63.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached fonttools-4.63.0-cp311-cp311-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Obtaining dependency information for kiwisolver>=1.3.1 from https://files.pythonhosted.org/packages/be/6c/28f17390b62b8f2f520e2915095b3c94d88681ecf0041e75389d9667f202/kiwisolver-1.5.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached kiwisolver-1.5.0-cp311-cp311-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in c:\users\tomato\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\tomato\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\tomato\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (12.2.0)
# Collecting pyparsing>=3 (from matplotlib)
#   Obtaining dependency information for pyparsing>=3 from https://files.pythonhosted.org/packages/10/bd/c038d7cc38edc1aa5bf91ab8068b63d4308c66c4c8bb3cbba7dfbc049f9c/pyparsing-3.3.2-py3-none-any.whl.metadata
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tomato\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\tomato\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.11.0-cp311-cp311-win_amd64.whl (9.3 MB)
# Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.63.0-cp311-cp311-win_amd64.whl (2.4 MB)
# Using cached kiwisolver-1.5.0-cp311-cp311-win_amd64.whl (73 kB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.0 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\tomato\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.2.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df.loc[df["   TG"] != -9999]["   TG"].hist()
# Out:
# <Axes: >

# %% [markdown]
# # Get certain cells

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG
# 0          1   35381 1860-01-01     21      0
# 1          1   35381 1860-01-02     46      0
# 2          1   35381 1860-01-03     31      0
# 3          1   35381 1860-01-04     37      0
# 4          1   35381 1860-01-05     31      0
# ...      ...     ...        ...    ...    ...
# 59316      1   35381 2022-05-27  -9999      9
# 59317      1   35381 2022-05-28  -9999      9
# 59318      1   35381 2022-05-29  -9999      9
# 59319      1   35381 2022-05-30  -9999      9
# 59320      1   35381 2022-05-31  -9999      9
#
# [59321 rows x 5 columns]

# %%
df.loc[df["    DATE"]=="1860-01-05"]
# Out:
#    STAID   SOUID       DATE     TG   Q_TG
# 4      1   35381 1860-01-05     31      0

# %%
df.loc[df["    DATE"]=="1860-01-05"]["   TG"].squeeze() / 10
# Out:
# np.float64(3.1)

# %%
df.loc[df["   TG"] == df["   TG"].max()]["    DATE"].squeeze()
# Out:
# Timestamp('1868-08-16 00:00:00')

# %%
df.loc[3,"   TG"] / 10
# Out:
# np.float64(3.7)

# %% [markdown]
# # Calculate a new column out of existing column

# %%
import numpy as np
df["TG0"] = df["   TG"].mask(df["   TG"] == -9999, np.nan)
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG     TG   TG0
# 0          1   35381 1860-01-01     21      0    2.1  21.0
# 1          1   35381 1860-01-02     46      0    4.6  46.0
# 2          1   35381 1860-01-03     31      0    3.1  31.0
# 3          1   35381 1860-01-04     37      0    3.7  37.0
# 4          1   35381 1860-01-05     31      0    3.1  31.0
# ...      ...     ...        ...    ...    ...    ...   ...
# 59316      1   35381 2022-05-27  -9999      9 -999.9   NaN
# 59317      1   35381 2022-05-28  -9999      9 -999.9   NaN
# 59318      1   35381 2022-05-29  -9999      9 -999.9   NaN
# 59319      1   35381 2022-05-30  -9999      9 -999.9   NaN
# 59320      1   35381 2022-05-31  -9999      9 -999.9   NaN
#
# [59321 rows x 7 columns]

# %%
df["TG"] = df["TG0"] / 10

# %%
df
# Out:
#        STAID   SOUID       DATE     TG   Q_TG   TG   TG0
# 0          1   35381 1860-01-01     21      0  2.1  21.0
# 1          1   35381 1860-01-02     46      0  4.6  46.0
# 2          1   35381 1860-01-03     31      0  3.1  31.0
# 3          1   35381 1860-01-04     37      0  3.7  37.0
# 4          1   35381 1860-01-05     31      0  3.1  31.0
# ...      ...     ...        ...    ...    ...  ...   ...
# 59316      1   35381 2022-05-27  -9999      9  NaN   NaN
# 59317      1   35381 2022-05-28  -9999      9  NaN   NaN
# 59318      1   35381 2022-05-29  -9999      9  NaN   NaN
# 59319      1   35381 2022-05-30  -9999      9  NaN   NaN
# 59320      1   35381 2022-05-31  -9999      9  NaN   NaN
#
# [59321 rows x 7 columns]

# %% [markdown]
# # Plotting

# %%
df[100:1000].plot(x="    DATE",y="TG", figsize=(15,3))
# Out:
# <Axes: xlabel='    DATE'>
